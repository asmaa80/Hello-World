# %% [markdown]
# #                                   'Lyon'

# %%
'date du début' et 'Date de fin'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=561x241 at 0x7FC1E260B8B0>

# %%
'date du début' et 'Date de fin'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=551x231 at 0x7FC1DC64E2E0>

# %%
'Moyenne, minimum, maximum de degrés Celsius, jour (08h_20h), Lyon '
'Moyenne, Maximum, Minimum de degrés Celsius, nuit (20h_08h), Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1191x621 at 0x7FC1E25E3B20>

# %%
'Moyenne, minimum, maximum de degrés Celsius, jour (08h_20h), Lyon '
'Moyenne, Maximum, Minimum de degrés Celsius, nuit (20h_08h), Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1181x612 at 0x7FC1E25E3670>

# %%
'Celsius tout le période de travailler jour par jour Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1261x411 at 0x7FC1E260B0D0>

# %%
'Celsius tout le période de travailler jour par jour Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1246x399 at 0x7FC1DC64E4F0>

# %%
'API et Celsius tout le période de travailler jour par jour Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1261x471 at 0x7FC1E260B280>

# %%
'API et Celsius tout le période de travailler jour par jour Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1249x456 at 0x7FC1DC64E400>

# %%
'nbval_Lyon' et 'nbval(Celsius)>28' et 'nbval(Celsius)>28 , jour (08h_20h) Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1131x521 at 0x7FC1E25E3040>

# %%
'nbval_Lyon' et 'nbval(Celsius)>28' et 'nbval(Celsius)>28 , jour (08h_20h) Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1114x511 at 0x7FC1DC639490>

# %%
'Moyenne de Celsius, (11 / 05-31 / 05), jour (08h-20h), Lyon' 
'Moyenne de Celsius, (11 / 05-31 / 05), nuit (20h-08h), Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1261x361 at 0x7FC1E260B490>

# %%
'Moyenne de Celsius, (11 / 05-31 / 05), jour (08h-20h), Lyon' 
'Moyenne de Celsius, (11 / 05-31 / 05), nuit (20h-08h), Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1248x353 at 0x7FC1DC64E1F0>

# %%
'Moyenne de Celsius,(01 / 06-30 / 06), jour (08h-20h), lyon'
'Moyenne de Celsius,(01 / 06-30 / 06), nuit (20h-08h), lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1251x311 at 0x7FC1E260B520>

# %%
'Moyenne de Celsius,(01 / 06-30 / 06), jour (08h-20h), lyon'
'Moyenne de Celsius,(01 / 06-30 / 06), nuit (20h-08h), lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1254x303 at 0x7FC1E2643D30>

# %%
'Moyenne de Celsius, (01 / 07-31 / 07), jour (08h-20h), Lyon'
'Moyenne de Celsius, (01 / 07-31 / 07), nuit (20h-08h), Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1277x311 at 0x7FC1E260BCD0>

# %%
'Moyenne de Celsius, (01 / 07-31 / 07), jour (08h-20h), Lyon'
'Moyenne de Celsius, (01 / 07-31 / 07), nuit (20h-08h), Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1252x302 at 0x7FC1DC64E3D0>

# %%
'Moyenne de Celsius, (01 / 08-31 / 08), jour (08h-20h), Lyon'
'Moyenne de Celsius, (01 / 08-31 / 08), nuit (20h-08h), lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1267x311 at 0x7FC1E25E3E20>

# %%
'Moyenne de Celsius, (01 / 08-31 / 08), jour (08h-20h), Lyon'
'Moyenne de Celsius, (01 / 08-31 / 08), nuit (20h-08h), lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1252x307 at 0x7FC1E2643F40>

# %%
'Moyenne de Celsius, (01 / 09-30 / 09), jour (08h-20h), Lyon'
'Moyenne de Celsius, (01 / 09-30 / 09), nuit (20h-08h), Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1267x311 at 0x7FC1E25E3C10>

# %%
'Moyenne de Celsius, (01 / 09-30 / 09), jour (08h-20h), Lyon'
'Moyenne de Celsius, (01 / 09-30 / 09), nuit (20h-08h), Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1253x306 at 0x7FC1DC64E460>

# %%
'Moyenne_Taux d’inconfort(Celsius)_Lyon'

# %%
'Moyenne_Taux d’inconfort(Celsius)_Lyon'

# %%
'Moyenne_Taux d’inconfort(Celsius)_Lyon(Aannée)'

# %%
'Moyenne_Taux d’inconfort(Celsius)_Lyon(Aannée)'

# %% [markdown]
# #                                'Grenoble'

# %%
'date du début' et 'Date de fin'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=798x351 at 0x7FC1E2643F10>

# %%
'date du début' et 'Date de fin'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=835x327 at 0x7FC1E25E3F10>

# %%
'Moyenne, minimum, maximum de degrés Celsius, jour (08h_20h), Grenoble '
'Moyenne, Maximum, Minimum de degrés Celsius, nuit (20h_08h), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1258x781 at 0x7FC1E25E3130>

# %%
'Moyenne, minimum, maximum de degrés Celsius, jour (08h_20h), Grenoble '
'Moyenne, Maximum, Minimum de degrés Celsius, nuit (20h_08h), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1251x768 at 0x7FC1E25E3FD0>

# %%
'API et Celsius tout le période de travailler jour par jour_Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1178x491 at 0x7FC1E25E3BE0>

# %%
'API et Celsius tout le période de travailler jour par jour_Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1256x507 at 0x7FC1E25E3940>

# %%
'nbval_Grenoble' et 'nbval(Celsius)>28' et 'nbval(Celsius)>28 , jour (08h_20h) Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1118x621 at 0x7FC1E25E3CA0>

# %%
'nbval_Grenoble' et 'nbval(Celsius)>28' et 'nbval(Celsius)>28 , jour (08h_20h) Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1116x616 at 0x7FC1E25E37C0>

# %%
'Moyenne de Celsius, (03 / 07-31 / 07), jour (08h-20h), Grenoble'
'Moyenne de Celsius, (03 / 07-31 / 07), nuit (20h-08h), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=738x681 at 0x7FC1E260BD30>

# %%
'Moyenne de Celsius, (03 / 07-31 / 07), jour (08h-20h), Grenoble'
'Moyenne de Celsius, (03 / 07-31 / 07), nuit (20h-08h), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1438x361 at 0x7FC1E2643FA0>

# %%
'Moyenne de Celsius, (03 / 07-31 / 07), jour (08h-20h), Grenoble'
'Moyenne de Celsius, (03 / 07-31 / 07), nuit (20h-08h), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=714x690 at 0x7FC1E25E3340>

# %%
'Moyenne de Celsius, (01 / 08-31 / 08), jour (08h-20h), Grenoble'
'Moyenne de Celsius, (01 / 08-31 / 08), nuit (20h-08h), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=738x752 at 0x7FC1E25E3DF0>

# %%
'Moyenne de Celsius, (01 / 08-31 / 08), jour (08h-20h), Grenoble'
'Moyenne de Celsius, (01 / 08-31 / 08), nuit (20h-08h), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1396x358 at 0x7FC1E260B2B0>

# %%
'Moyenne de Celsius, (01 / 08-31 / 08), jour (08h-20h), Grenoble'
'Moyenne de Celsius, (01 / 08-31 / 08), nuit (20h-08h), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=708x722 at 0x7FC1E25E37F0>

# %%
'Moyenne de Celsius, (01 / 09-30 / 09), jour (08h-20h), Grenoble'
'Moyenne de Celsius, (01 / 09-30 / 09), nuit (20h-08h), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=728x772 at 0x7FC1E25E3A90>

# %%
'Moyenne de Celsius, (01 / 09-30 / 09), jour (08h-20h), Grenoble'
'Moyenne de Celsius, (01 / 09-30 / 09), nuit (20h-08h), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1401x356 at 0x7FC1E260B1F0>

# %%
'Moyenne de Celsius, (01 / 09-30 / 09), jour (08h-20h), Grenoble'
'Moyenne de Celsius, (01 / 09-30 / 09), nuit (20h-08h), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=701x767 at 0x7FC1DC64E3A0>

# %%
'Moyenne_Taux d’inconfort(Celsius)_Grenoble(été) Grenoble'

# %%
'Moyenne_Taux d’inconfort(Celsius)_Grenoble(été) Grenoble'

# %%
'Moyenne_Taux d’inconfort(Celsius)_Grenoble(Aannée)'

# %%
'Moyenne_Taux d’inconfort(Celsius)_Grenoble(Aannée)'
